# %% [markdown]
# <a href="https://colab.research.google.com/github/solanods/data_analysis/blob/main/logs_final_setra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('drive/MyDrive/moodle_databases/logs_setra.csv')
pd.set_option('display.max_rows', 3000)

# %%
# change the case
df['Nome completo'] = df['Nome completo'].str.title()

# %%
atividades = 210

# %%
grouped = df.groupby('Data')['Nome completo'].value_counts().sort_index(ascending=True)

# %%
grouped
# Out:
# Data        Nome completo
# 1/01/2022   Adão Derli Cavalheiro Barcellos Filho      7
#             Diego De Oliveira Otto                     2
#             Flávia Pereira Strattmann                  6
#             Guilherme Nunes Pereira                    3
#             Kely De Araújo                             3
#             Rodrigo Vieira Dos Santos                  4
#             Simone Rodrigues                           2
#             Tatiane Alves Vieira                       1
# 1/12/2021   Andrei Luft Diniz                          7
#             Carlos Roberto Neto Coitinho               2
#             Cristiano Da Silva Cruz                   23
#             Diego De Oliveira Otto                    11
#             Edna Martins Dahm                          1
#             Fellipe Chaves Soares                     13
#             Franco Klein                               9
#             Guilherme Nunes Pereira                   20
# ...

# %%
grouped/atividades
# Out:
# Data        Nome completo
# 1/01/2022   Adão Derli Cavalheiro Barcellos Filho    0.033333
#             Diego De Oliveira Otto                   0.009524
#             Flávia Pereira Strattmann                0.028571
#             Guilherme Nunes Pereira                  0.014286
#             Kely De Araújo                           0.014286
#             Rodrigo Vieira Dos Santos                0.019048
#             Simone Rodrigues                         0.009524
#             Tatiane Alves Vieira                     0.004762
# 1/12/2021   Andrei Luft Diniz                        0.033333
#             Carlos Roberto Neto Coitinho             0.009524
#             Cristiano Da Silva Cruz                  0.109524
#             Diego De Oliveira Otto                   0.052381
#             Edna Martins Dahm                        0.004762
#             Fellipe Chaves Soares                    0.061905
#             Franco Klein                             0.042857
# ...

# %%
import numpy as np

# %%
porcentagem = grouped/atividades * 100

# %%
porcentagem
# Out:
# Data        Nome completo
# 1/01/2022   Adão Derli Cavalheiro Barcellos Filho      3.333333
#             Diego De Oliveira Otto                     0.952381
#             Flávia Pereira Strattmann                  2.857143
#             Guilherme Nunes Pereira                    1.428571
#             Kely De Araújo                             1.428571
#             Rodrigo Vieira Dos Santos                  1.904762
#             Simone Rodrigues                           0.952381
#             Tatiane Alves Vieira                       0.476190
# 1/12/2021   Andrei Luft Diniz                          3.333333
#             Carlos Roberto Neto Coitinho               0.952381
#             Cristiano Da Silva Cruz                   10.952381
#             Diego De Oliveira Otto                     5.238095
#             Edna Martins Dahm                          0.476190
#             Fellipe Chaves Soares                      6.190476
# ...
