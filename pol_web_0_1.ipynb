# %% [markdown]
# <a href="https://colab.research.google.com/github/solanods/data_analysis/blob/main/pol_web_0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/PRMS_04_ABR_2022.xlsm', sheet_name='2', index_col=None)

# %%
pd.set_option('display.max_rows', 200)

# %%
pd.set_option('display.max_columns', 200)

# %%
df = df.rename({'Unnamed: 0': '0',
                'Unnamed: 1': '1',
                'Unnamed: 2': 'MISSÃO',
                'Unnamed: 3': 'OPERADOR',
                'Unnamed: 4': '4',
                'Unnamed: 5': 'MISSÃO_TUE',
                'Unnamed: 6': 'TREM',
                'Unnamed: 7': 'HORA_MR',
                'Unnamed: 8': 'DEST_V2',
                'Unnamed: 9': 'MISSÃO_CHEGADA',
                'Unnamed: 10': 'OPERADOR_CHEGADA',
                'Unnamed: 11': 'RENDICAO',
                'Unnamed: 12': 'HORA_CHEGADA',
                'Unnamed: 13': '13',
                'Unnamed: 14': '14',
                'Unnamed: 15': '15',
                'Unnamed: 16': 'HORA_NORTE',
                'Unnamed: 17': 'ORIGEM',
                'Unnamed: 18': 'DEST_V2',
                'Unnamed: 19': 'OBS',
                'Unnamed: 20': 'TREM_',
                'Unnamed: 21': 'MISSAO_',
                'Unnamed: 22': 'OPERADOR_'}, axis = 1)

# %%
df = df.drop(columns=['0', '1', '4', '13', '14', '15'])

# %%
df = df[5:180]

# %%
df = df.fillna(value='-')

# %%
df
# Out:
#     MISSÃO            OPERADOR MISSÃO_TUE TREM   HORA_MR DEST_V2  \
# 5      11N             Roberto        A08  231  05:07:00      NH
# 6      12N                SAUL        A01  227  05:22:00      NH
# 7      01M           HORTENCIA        A02  236  05:37:00      NH
# 8      02M             VALDOIR        A03  226  05:52:00      NH
# 9      03M               JULIO        A04  232  06:07:00      NH
# 10     04M             TEOFILO        A05  237  06:22:00      NH
# 11     05M              VALDIR        A06  238  06:36:00      NH
# 12     06M              SOARES        A07  239  06:51:00      NH
# 13     07M              JUNIOR        A08  229  07:06:00      NH
# 14     08M             TAVARES        A01  231  07:21:00      NH
# 15     09M           Jaqueline        A02  227  07:36:00      NH
# 16     10M                Paim        A03  236  07:51:00      NH
# 17     11M               Jorge        A04  226  08:06:00      NH
# ...

# %%
parse = df.to_html()

# %%
parse
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>MISSÃO</th>\n      <th>OPERADOR</th>\n      <th>MISSÃO_TUE</th>\n      <th>TREM</th>\n      <th>HORA_MR</th>\n      <th>DEST_V2</th>\n      <th>MISSÃO_CHEGADA</th>\n      <th>OPERADOR_CHEGADA</th>\n      <th>RENDICAO</th>\n      <th>HORA_CHEGADA</th>\n      <th>HORA_NORTE</th>\n      <th>ORIGEM</th>\n      <th>DEST_V2</th>\n      <th>OBS</th>\n      <th>TREM_</th>\n      <th>MISSAO_</th>\n      <th>OPERADOR_</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>5</th>\n      <td>11N</td>\n      <td>Roberto</td>\n      <td>A08</td>\n      <td>231</td>\n      <td>05:07:00</td>\n      <td>NH</td>\n      <td>-</td>\n      <td>-</td>\n      <td>-</td>\n      <td>-</td>\n      <td>05:07:00</td>\n      <td>NH</td>\n      <td>MR</td>\n      <td>-</td>\n      <td>232</td>\n      <td>04N</td>\n      <td>Back</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>12N</td>\n   
# ...

# %%
# write html to file
text_file = open("index.html", "w")
text_file.write(parse)
text_file.close()
